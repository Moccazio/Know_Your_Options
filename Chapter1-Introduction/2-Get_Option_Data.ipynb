# %% [markdown]
# # Get Option Data
#
# An option chain is a listing of all available options contracts for a given security. It shows all listed puts, calls, their expiration, strike prices, and volume and pricing information for a single underlying asset within a given maturity period. The chain will typically be categorized by expiration date and segmented by calls vs. puts.

# %%
import pandas as pd
import numpy as np 
import  pandas_datareader as pdr
from pandas_datareader.yahoo.options import Options
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import bs4 as bs
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Example: Apple Stock

# %%
pdr.get_quote_yahoo("aapl")
# Out:
#      language region quoteType         quoteSourceName  triggerable currency  \
# AAPL    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
#
#       regularMarketChange  regularMarketChangePercent  regularMarketTime  \
# AAPL             6.529999                    5.385122         1614632402
#
#       regularMarketPrice  ...   shortName    longName  messageBoardId  \
# AAPL              127.79  ...  Apple Inc.  Apple Inc.     finmb_24937
#
#       exchangeTimezoneName  exchangeTimezoneShortName  gmtOffSetMilliseconds  \
# AAPL      America/New_York                        EST              -18000000
#
#          market  esgPopulated  displayName   price
# AAPL  us_market         False        Apple  127.79
#
# [1 rows x 74 columns]

# %%
aapl = Options('aapl')
calls = aapl.get_call_data()

# %%
help(Options.get_options_data)
# Out:
# Help on function get_options_data in module pandas_datareader.yahoo.options:
#
# get_options_data(self, month=None, year=None, expiry=None)
#     ***Experimental***
#     Gets call/put data for the stock with the expiration data in the
#     given month and year
#
#     Parameters
#     ----------
#     month : number, int, optional(default=None)
#         The month the options expire. This should be either 1 or 2
#         digits.
#
#     year : number, int, optional(default=None)
#         The year the options expire. This should be a 4 digit int.
#
#     expiry : date-like or convertible or
#              list-like object, optional (default=None)
#         The date (or dates) when options expire (defaults to current month)
#
#     Returns
#     -------
#     pandas.DataFrame
#         A DataFrame with requested options data.
#
#         Index:
#             Strike: Option strike, int
#             Expiry: Option expiry, Timestamp
#             Type: Call or Put, string
#             Symbol: Option symbol as reported on Yahoo, string
#         Columns:
#             Last: Last option price, float
#             Chg: Change from prior day, float
#             PctChg: Change from prior day in percent, float
#             Bid: Bid price, float
#             Ask: Ask price, float
#             Vol: Volume traded, int64
#             Open_Int: Open interest, int64
#             IsNonstandard: True if the the deliverable is not 100 shares,
#                            otherwise False
#             Underlying: Ticker of the underlying security, string
#             Underlying_Price: Price of the underlying security, float64
#             Quote_Time: Time of the quote, Timestamp
#             Last_Trade_Date: Time of the last trade for this expiry
#                              and strike, Timestamp
#             IV: Implied volatility, float
#             JSON: Parsed json object, json
#                 Useful to extract other returned key/value pairs as needed
#
#     Notes
#     -----
#     Note: Format of returned DataFrame is dependent
#           on Yahoo and may change.
#
#     When called, this function will add instance variables named
#     calls and puts. See the following example:
#
#         >>> aapl = Options('aapl', 'yahoo')  # Create object
#         >>> aapl.calls  # will give an AttributeError
#         >>> aapl.get_options()  # Get data and set ivars
#         >>> aapl.calls  # Doesn't throw AttributeError
#
#     Also note that aapl.calls and appl.puts will always be the calls
#     and puts for the next expiry. If the user calls this method with
#     a different expiry, the ivar will be named callsYYMMDD or putsYYMMDD,
#     where YY, MM and DD are, respectively, two digit representations of
#     the year, month and day for the expiry of the options.

# %%
calls_filtered = calls[['Last', 'Bid', 'Ask', 'Chg', 'Vol', 'Open_Int', 'IV', 'Underlying_Price', 'Last_Trade_Date', 'Root']]
calls_filtered
# Out:
#                                              Last    Bid    Ask       Chg  \
# Strike Expiry     Type Symbol
# 70.0   2021-02-26 call AAPL210226C00070000  53.98  54.55  55.75  1.930000
# 75.0   2021-02-26 call AAPL210226C00075000  54.15  49.55  50.75  0.000000
# 80.0   2021-02-26 call AAPL210226C00080000  43.80  44.50  45.75  2.160000
# 85.0   2021-02-26 call AAPL210226C00085000  52.85  39.10  40.75  0.000000
# 90.0   2021-02-26 call AAPL210226C00090000  35.13  34.55  35.50  1.530003
# ...                                           ...    ...    ...       ...
# 185.0  2021-02-26 call AAPL210226C00185000   0.01   0.00   0.01  0.000000
# 190.0  2021-02-26 call AAPL210226C00190000   0.01   0.00   0.01  0.000000
# 195.0  2021-02-26 call AAPL210226C00195000   0.01   0.00   0.01  0.000000
# 200.0  2021-02-26 call AAPL210226C00200000   0.01   0.00   0.01  0.000000
# 205.0  2021-02-26 call AAPL210226C00205000   0.01   0.00   0.01  0.000000
#
#                                              Vol  Open_Int        IV  \
# Strike Expiry     Type Symbol
# 70.0   2021-02-26 call AAPL210226C00070000  15.0      37.0  3.527345
# 75.0   2021-02-26 call AAPL210226C00075000   1.0      11.0  3.160158
# 80.0   2021-02-26 call AAPL210226C00080000   1.0       5.0  2.812503
# 85.0   2021-02-26 call AAPL210226C00085000  19.0      20.0  2.486332
# 90.0   2021-02-26 call AAPL210226C00090000  23.0      69.0  1.828126
# ...                                          ...       ...       ...
# 185.0  2021-02-26 call AAPL210226C00185000   5.0    1767.0  1.375003
# 190.0  2021-02-26 call AAPL210226C00190000   1.0    1251.0  1.468753
# 195.0  2021-02-26 call AAPL210226C00195000   5.0     522.0  1.562502
# 200.0  2021-02-26 call AAPL210226C00200000   4.0    3146.0  1.625002
# 205.0  2021-02-26 call AAPL210226C00205000  32.0    1444.0  1.687502
#
#                                             Underlying_Price  \
# Strike Expiry     Type Symbol
# 70.0   2021-02-26 call AAPL210226C00070000            125.35
# 75.0   2021-02-26 call AAPL210226C00075000            125.35
# 80.0   2021-02-26 call AAPL210226C00080000            125.35
# 85.0   2021-02-26 call AAPL210226C00085000            125.35
# 90.0   2021-02-26 call AAPL210226C00090000            125.35
# ...                                                      ...
# 185.0  2021-02-26 call AAPL210226C00185000            125.35
# 190.0  2021-02-26 call AAPL210226C00190000            125.35
# 195.0  2021-02-26 call AAPL210226C00195000            125.35
# 200.0  2021-02-26 call AAPL210226C00200000            125.35
# 205.0  2021-02-26 call AAPL210226C00205000            125.35
#
#                                                Last_Trade_Date  Root
# Strike Expiry     Type Symbol
# 70.0   2021-02-26 call AAPL210226C00070000 2021-02-24 18:05:04  AAPL
# 75.0   2021-02-26 call AAPL210226C00075000 2021-02-19 18:37:11  AAPL
# 80.0   2021-02-26 call AAPL210226C00080000 2021-02-23 17:14:50  AAPL
# 85.0   2021-02-26 call AAPL210226C00085000 2021-02-09 15:41:59  AAPL
# 90.0   2021-02-26 call AAPL210226C00090000 2021-02-24 20:52:58  AAPL
# ...                                                        ...   ...
# 185.0  2021-02-26 call AAPL210226C00185000 2021-02-18 16:57:32  AAPL
# 190.0  2021-02-26 call AAPL210226C00190000 2021-02-19 16:03:48  AAPL
# 195.0  2021-02-26 call AAPL210226C00195000 2021-02-22 18:56:53  AAPL
# 200.0  2021-02-26 call AAPL210226C00200000 2021-02-24 20:04:44  AAPL
# 205.0  2021-02-26 call AAPL210226C00205000 2021-02-22 20:27:20  AAPL
#
# [72 rows x 10 columns]

# %% [markdown]
# ### Get the Options for all SP500 Stocks

# %%
def save_sp500_tickers():

    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'html')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        if not '.' in ticker:
            tickers.append(ticker.replace('\n',''))
        
    return tickers

symbols = save_sp500_tickers()

# %%
def call_options(sym):
    stk = Options(sym)
    dates = stk.expiry_dates
    calls_merged = []
    for d in dates:
            calls_ = stk.get_call_data(expiry=d)
            calls_filtered = calls_[['Last', 'Bid', 'Ask', 'Chg', 'Vol', 'Open_Int', 'IV', 'Underlying_Price', 'Last_Trade_Date', 'Root']].reset_index()
            calls_filtered = calls_filtered [['Strike', 'Expiry', 'Type','Last', 'Bid', 'Ask', 'Chg', 'Vol', 'Open_Int', 'IV', 'Underlying_Price', 'Root']]
            calls_filtered.columns =  [['Strike', 'Expiry', 'Type','Last', 'Bid', 'Ask', 'Chg', 'Vol', 'Open_Int', 'IV', 'Underlying_Price', 'Symbol']]     
            calls_merged.append(calls_filtered)   
    calls_df = pd.concat(calls_merged, axis=0) 
    return calls_df

def put_options(sym):
    stk = Options(sym)
    dates = stk.expiry_dates
    puts_merged = []
    for d in dates:
            puts_ = stk.get_put_data(expiry=d)
            puts_filtered = puts_[['Last', 'Bid', 'Ask', 'Chg', 'Vol', 'Open_Int', 'IV', 'Underlying_Price', 'Last_Trade_Date', 'Root']].reset_index()
            puts_filtered = puts_filtered [['Strike', 'Expiry', 'Type','Last', 'Bid', 'Ask', 'Chg', 'Vol', 'Open_Int', 'IV', 'Underlying_Price', 'Root']]
            puts_filtered.columns =  [['Strike', 'Expiry', 'Type','Last', 'Bid', 'Ask', 'Chg', 'Vol', 'Open_Int', 'IV', 'Underlying_Price', 'Symbol']]                    
            puts_merged.append(puts_filtered)
        
    puts_df = pd.concat(puts_merged, axis=0) 
    return puts_df

# %%
call_options("AAPL")
# Out:
#    Strike     Expiry  Type   Last  Bid  Ask  Chg     Vol Open_Int        IV  \
# 0    70.0 2021-03-05  call  53.44  0.0  0.0  0.0     5.0      9.0  0.000010
# 1    75.0 2021-03-05  call  48.65  0.0  0.0  0.0    20.0     43.0  0.000010
# 2    80.0 2021-03-05  call  47.63  0.0  0.0  0.0     5.0    145.0  0.000010
# 3    81.0 2021-03-05  call  40.90  0.0  0.0  0.0     NaN     40.0  0.000010
# 4    82.0 2021-03-05  call  39.65  0.0  0.0  0.0     NaN      0.0  0.000010
# ..    ...        ...   ...    ...  ...  ...  ...     ...      ...       ...
# 24  185.0 2023-03-17  call  11.25  0.0  0.0  0.0  1268.0   7105.0  0.062509
# 25  190.0 2023-03-17  call  10.70  0.0  0.0  0.0    22.0   2994.0  0.062509
# 26  195.0 2023-03-17  call   9.82  0.0  0.0  0.0    16.0    733.0  0.062509
# 27  200.0 2023-03-17  call   9.20  0.0  0.0  0.0   286.0   9493.0  0.062509
# 28  210.0 2023-03-17  call   8.10  0.0  0.0  0.0   573.0   4401.0  0.062509
#
#    Underlying_Price Symbol
# 0             128.5   AAPL
# 1             128.5   AAPL
# 2             128.5   AAPL
# 3             128.5   AAPL
# 4             128.5   AAPL
# ..              ...    ...
# 24            128.5   AAPL
# 25            128.5   AAPL
# 26            128.5   AAPL
# 27            128.5   AAPL
# 28            128.5   AAPL
#
# [1372 rows x 12 columns]

# %%
put_options("AAPL")
# Out:
#    Strike     Expiry Type   Last  Bid  Ask  Chg    Vol Open_Int        IV  \
# 0    70.0 2021-03-05  put   0.01  0.0  0.0  0.0  101.0    936.0  0.500005
# 1    75.0 2021-03-05  put   0.01  0.0  0.0  0.0    4.0    337.0  0.500005
# 2    80.0 2021-03-05  put   0.01  0.0  0.0  0.0   10.0   2176.0  0.500005
# 3    81.0 2021-03-05  put   0.02  0.0  0.0  0.0   14.0     62.0  0.500005
# 4    82.0 2021-03-05  put   0.01  0.0  0.0  0.0    6.0     16.0  0.500005
# ..    ...        ...  ...    ...  ...  ...  ...    ...      ...       ...
# 24  185.0 2023-03-17  put  66.80  0.0  0.0  0.0    2.0      4.0  0.000010
# 25  190.0 2023-03-17  put  68.81  0.0  0.0  0.0    3.0     85.0  0.000010
# 26  195.0 2023-03-17  put  79.56  0.0  0.0  0.0    6.0     27.0  0.000010
# 27  200.0 2023-03-17  put  81.00  0.0  0.0  0.0    2.0     94.0  0.000010
# 28  210.0 2023-03-17  put  92.47  0.0  0.0  0.0    3.0     57.0  0.000010
#
#    Underlying_Price Symbol
# 0             128.5   AAPL
# 1             128.5   AAPL
# 2             128.5   AAPL
# 3             128.5   AAPL
# 4             128.5   AAPL
# ..              ...    ...
# 24            128.5   AAPL
# 25            128.5   AAPL
# 26            128.5   AAPL
# 27            128.5   AAPL
# 28            128.5   AAPL
#
# [1338 rows x 12 columns]

# %%
def _get_option_data(symbols):
    
    symbol_count = len(symbols)
    N = symbol_count
    missing_symbols = []
    _merged = []
    for i, sym in enumerate(symbols, start=1):
        if not pd.isnull(sym):
            try:
                calls_df = call_options(sym)
                puts_df = put_options(sym)
                first_concat = pd.concat([calls_df, puts_df], axis=0)
                _merged.append(first_concat)
                
            except Exception as e:
                print(e, sym)
                missing_symbols.append(sym)
            N -= 1
            pct_total_left = (N / symbol_count)
            print('{}..[done] | {} of {} symbols collected | {:>.2%}'.format(\
                                                            sym, i, symbol_count, pct_total_left))
    option_df = pd.concat(_merged, axis=0) 
    print(missing_symbols)
    return option_df

# %% [raw]
# def _get_option_data(symbols, hdf_name):
#
#     options_hdf = pd.HDFStore(_option_data + 'hdf/'+hdf_name+'.h5')
#
#     symbol_count = len(symbols)
#     N = symbol_count
#     missing_symbols = []
#     _merged = []
#     for i, sym in enumerate(symbols, start=1):
#         if not pd.isnull(sym):
#             try:
#                 calls_df = call_options(sym)
#                 puts_df = put_options(sym)
#                 first_concat = pd.concat([calls_df, puts_df], axis=0)
#                 _merged.append(first_concat)
#                 first_concat.to_excel(_option_data+'xlsx/stocks/'+sym+'.xlsx')
#                 options_hdf[sym] = first_concat
#
#             except Exception as e:
#                 print(e, sym)
#                 missing_symbols.append(sym)
#             N -= 1
#             pct_total_left = (N / symbol_count)
#             print('{}..[done] | {} of {} symbols collected | {:>.2%}'.format(\
#                                                             sym, i, symbol_count, pct_total_left))
#     options_hdf.close()
#     option_df = pd.concat(_merged, axis=0)
#     print(missing_symbols)
#     return option_df

# %% [markdown]
# ### Get Option Data

# %%
_df = _get_option_data(symbols)
# Out:
# MMM..[done] | 1 of 503 symbols collected | 99.80%
# ABT..[done] | 2 of 503 symbols collected | 99.60%
# ABBV..[done] | 3 of 503 symbols collected | 99.40%
# ABMD..[done] | 4 of 503 symbols collected | 99.20%
# ACN..[done] | 5 of 503 symbols collected | 99.01%
# ATVI..[done] | 6 of 503 symbols collected | 98.81%
# ADBE..[done] | 7 of 503 symbols collected | 98.61%
# AMD..[done] | 8 of 503 symbols collected | 98.41%
# AAP..[done] | 9 of 503 symbols collected | 98.21%
# AES..[done] | 10 of 503 symbols collected | 98.01%
# AFL..[done] | 11 of 503 symbols collected | 97.81%
# A..[done] | 12 of 503 symbols collected | 97.61%
# APD..[done] | 13 of 503 symbols collected | 97.42%
# AKAM..[done] | 14 of 503 symbols collected | 97.22%
# ALK..[done] | 15 of 503 symbols collected | 97.02%
# ALB..[done] | 16 of 503 symbols collected | 96.82%
# ARE..[done] | 17 of 503 symbols collected | 96.62%
# ALXN..[done] | 18 of 503 symbols collected | 96.42%
# ALGN..[done] | 19 of 503 symbols collected | 96.22%
# ALLE..[done] | 20 of 503 symbols collected | 96.02%
# LNT..[done] | 21 of 503 symbols collected | 95.83%
# ALL..[done] | 22 of 503 symbols collected | 95.63%
# GOOGL..[done] | 23 of 503 symbols collected | 95.43%
# GOOG..[done] | 24 of 503 symbols collected | 95.23%
# MO..[done] | 25 of 503 symbols collected | 95.03%
# AMZN..[done] | 26 of 503 symbols collected | 94.83%
# AMCR..[done] | 27 of 503 symbols collected | 94.63%
# AEE..[done] | 28 of 503 symbols collected | 94.43%
# AAL..[done] | 29 of 503 symbols collected | 94.23%
# AEP..[done] | 30 of 503 symbols collected | 94.04%
# AXP..[done] | 31 of 503 symbols collected | 93.84%
# AIG..[done] | 32 of 503 symbols collected | 93.64%
# AMT..[done] | 33 of 503 symbols collected | 93.44%
# AWK..[done] | 34 of 503 symbols collected | 93.24%
# AMP..[done] | 35 of 503 symbols collected | 93.04%
# ABC..[done] | 36 of 503 symbols collected | 92.84%
# AME..[done] | 37 of 503 symbols collected | 92.64%
# AMGN..[done] | 38 of 503 symbols collected | 92.45%
# APH..[done] | 39 of 503 symbols collected | 92.25%
# ADI..[done] | 40 of 503 symbols collected | 92.05%
# ANSS..[done] | 41 of 503 symbols collected | 91.85%
# ANTM..[done] | 42 of 503 symbols collected | 91.65%
# AON..[done] | 43 of 503 symbols collected | 91.45%
# AOS..[done] | 44 of 503 symbols collected | 91.25%
# APA..[done] | 45 of 503 symbols collected | 91.05%
# AAPL..[done] | 46 of 503 symbols collected | 90.85%
# AMAT..[done] | 47 of 503 symbols collected | 90.66%
# APTV..[done] | 48 of 503 symbols collected | 90.46%
# 'Requested level (Expiry) does not match index name (None)' ADM
# ADM..[done] | 49 of 503 symbols collected | 90.26%
# ANET..[done] | 50 of 503 symbols collected | 90.06%
# AJG..[done] | 51 of 503 symbols collected | 89.86%
# AIZ..[done] | 52 of 503 symbols collected | 89.66%
# T..[done] | 53 of 503 symbols collected | 89.46%
# ATO..[done] | 54 of 503 symbols collected | 89.26%
# ADSK..[done] | 55 of 503 symbols collected | 89.07%
# ADP..[done] | 56 of 503 symbols collected | 88.87%
# AZO..[done] | 57 of 503 symbols collected | 88.67%
# AVB..[done] | 58 of 503 symbols collected | 88.47%
# AVY..[done] | 59 of 503 symbols collected | 88.27%
# BKR..[done] | 60 of 503 symbols collected | 88.07%
# BLL..[done] | 61 of 503 symbols collected | 87.87%
# BAC..[done] | 62 of 503 symbols collected | 87.67%
# BK..[done] | 63 of 503 symbols collected | 87.48%
# BAX..[done] | 64 of 503 symbols collected | 87.28%
# BDX..[done] | 65 of 503 symbols collected | 87.08%
# BBY..[done] | 66 of 503 symbols collected | 86.88%
# BIO..[done] | 67 of 503 symbols collected | 86.68%
# 'Requested level (Expiry) does not match index name (None)' BIIB
# BIIB..[done] | 68 of 503 symbols collected | 86.48%
# BLK..[done] | 69 of 503 symbols collected | 86.28%
# BA..[done] | 70 of 503 symbols collected | 86.08%
# BKNG..[done] | 71 of 503 symbols collected | 85.88%
# 'Requested level (Expiry) does not match index name (None)' BWA
# BWA..[done] | 72 of 503 symbols collected | 85.69%
# BXP..[done] | 73 of 503 symbols collected | 85.49%
# BSX..[done] | 74 of 503 symbols collected | 85.29%
# BMY..[done] | 75 of 503 symbols collected | 85.09%
# AVGO..[done] | 76 of 503 symbols collected | 84.89%
# BR..[done] | 77 of 503 symbols collected | 84.69%
# CHRW..[done] | 78 of 503 symbols collected | 84.49%
# COG..[done] | 79 of 503 symbols collected | 84.29%
# CDNS..[done] | 80 of 503 symbols collected | 84.10%
# CPB..[done] | 81 of 503 symbols collected | 83.90%
# COF..[done] | 82 of 503 symbols collected | 83.70%
# CAH..[done] | 83 of 503 symbols collected | 83.50%
# KMX..[done] | 84 of 503 symbols collected | 83.30%
# CCL..[done] | 85 of 503 symbols collected | 83.10%
# CARR..[done] | 86 of 503 symbols collected | 82.90%
# CTLT..[done] | 87 of 503 symbols collected | 82.70%
# CAT..[done] | 88 of 503 symbols collected | 82.50%
# CBOE..[done] | 89 of 503 symbols collected | 82.31%
# CBRE..[done] | 90 of 503 symbols collected | 82.11%
# CDW..[done] | 91 of 503 symbols collected | 81.91%
# CE..[done] | 92 of 503 symbols collected | 81.71%
# CNC..[done] | 93 of 503 symbols collected | 81.51%
# CNP..[done] | 94 of 503 symbols collected | 81.31%
# CERN..[done] | 95 of 503 symbols collected | 81.11%
# 'Requested level (Expiry) does not match index name (None)' CF
# CF..[done] | 96 of 503 symbols collected | 80.91%
# 'Requested level (Expiry) does not match index name (None)' SCHW
# SCHW..[done] | 97 of 503 symbols collected | 80.72%
# CHTR..[done] | 98 of 503 symbols collected | 80.52%
# CVX..[done] | 99 of 503 symbols collected | 80.32%
# CMG..[done] | 100 of 503 symbols collected | 80.12%
# CB..[done] | 101 of 503 symbols collected | 79.92%
# CHD..[done] | 102 of 503 symbols collected | 79.72%
# CI..[done] | 103 of 503 symbols collected | 79.52%
# CINF..[done] | 104 of 503 symbols collected | 79.32%
# CTAS..[done] | 105 of 503 symbols collected | 79.13%
# CSCO..[done] | 106 of 503 symbols collected | 78.93%
# C..[done] | 107 of 503 symbols collected | 78.73%
# CFG..[done] | 108 of 503 symbols collected | 78.53%
# CTXS..[done] | 109 of 503 symbols collected | 78.33%
# CLX..[done] | 110 of 503 symbols collected | 78.13%
# CME..[done] | 111 of 503 symbols collected | 77.93%
# CMS..[done] | 112 of 503 symbols collected | 77.73%
# KO..[done] | 113 of 503 symbols collected | 77.53%
# CTSH..[done] | 114 of 503 symbols collected | 77.34%
# CL..[done] | 115 of 503 symbols collected | 77.14%
# CMCSA..[done] | 116 of 503 symbols collected | 76.94%
# CMA..[done] | 117 of 503 symbols collected | 76.74%
# CAG..[done] | 118 of 503 symbols collected | 76.54%
# 'Requested level (Expiry) does not match index name (None)' COP
# COP..[done] | 119 of 503 symbols collected | 76.34%
# ED..[done] | 120 of 503 symbols collected | 76.14%
# STZ..[done] | 121 of 503 symbols collected | 75.94%
# COO..[done] | 122 of 503 symbols collected | 75.75%
# CPRT..[done] | 123 of 503 symbols collected | 75.55%
# GLW..[done] | 124 of 503 symbols collected | 75.35%
# CTVA..[done] | 125 of 503 symbols collected | 75.15%
# COST..[done] | 126 of 503 symbols collected | 74.95%
# CCI..[done] | 127 of 503 symbols collected | 74.75%
# CSX..[done] | 128 of 503 symbols collected | 74.55%
# CMI..[done] | 129 of 503 symbols collected | 74.35%
# CVS..[done] | 130 of 503 symbols collected | 74.16%
# DHI..[done] | 131 of 503 symbols collected | 73.96%
# DHR..[done] | 132 of 503 symbols collected | 73.76%
# DRI..[done] | 133 of 503 symbols collected | 73.56%
# DVA..[done] | 134 of 503 symbols collected | 73.36%
# DE..[done] | 135 of 503 symbols collected | 73.16%
# DAL..[done] | 136 of 503 symbols collected | 72.96%
# XRAY..[done] | 137 of 503 symbols collected | 72.76%
# 'Requested level (Expiry) does not match index name (None)' DVN
# DVN..[done] | 138 of 503 symbols collected | 72.56%
# 'Requested level (Expiry) does not match index name (None)' DXCM
# DXCM..[done] | 139 of 503 symbols collected | 72.37%
# FANG..[done] | 140 of 503 symbols collected | 72.17%
# DLR..[done] | 141 of 503 symbols collected | 71.97%
# DFS..[done] | 142 of 503 symbols collected | 71.77%
# DISCA..[done] | 143 of 503 symbols collected | 71.57%
# DISCK..[done] | 144 of 503 symbols collected | 71.37%
# DISH..[done] | 145 of 503 symbols collected | 71.17%
# DG..[done] | 146 of 503 symbols collected | 70.97%
# DLTR..[done] | 147 of 503 symbols collected | 70.78%
# D..[done] | 148 of 503 symbols collected | 70.58%
# DPZ..[done] | 149 of 503 symbols collected | 70.38%
# DOV..[done] | 150 of 503 symbols collected | 70.18%
# 'Requested level (Expiry) does not match index name (None)' DOW
# DOW..[done] | 151 of 503 symbols collected | 69.98%
# DTE..[done] | 152 of 503 symbols collected | 69.78%
# DUK..[done] | 153 of 503 symbols collected | 69.58%
# DRE..[done] | 154 of 503 symbols collected | 69.38%
# DD..[done] | 155 of 503 symbols collected | 69.18%
# DXC..[done] | 156 of 503 symbols collected | 68.99%
# EMN..[done] | 157 of 503 symbols collected | 68.79%
# ETN..[done] | 158 of 503 symbols collected | 68.59%
# EBAY..[done] | 159 of 503 symbols collected | 68.39%
# ECL..[done] | 160 of 503 symbols collected | 68.19%
# EIX..[done] | 161 of 503 symbols collected | 67.99%
# EW..[done] | 162 of 503 symbols collected | 67.79%
# EA..[done] | 163 of 503 symbols collected | 67.59%
# EMR..[done] | 164 of 503 symbols collected | 67.40%
# ENPH..[done] | 165 of 503 symbols collected | 67.20%
# ETR..[done] | 166 of 503 symbols collected | 67.00%
# 'Requested level (Expiry) does not match index name (None)' EOG
# EOG..[done] | 167 of 503 symbols collected | 66.80%
# EFX..[done] | 168 of 503 symbols collected | 66.60%
# EQIX..[done] | 169 of 503 symbols collected | 66.40%
# EQR..[done] | 170 of 503 symbols collected | 66.20%
# ESS..[done] | 171 of 503 symbols collected | 66.00%
# EL..[done] | 172 of 503 symbols collected | 65.81%
# ETSY..[done] | 173 of 503 symbols collected | 65.61%
# EVRG..[done] | 174 of 503 symbols collected | 65.41%
# ES..[done] | 175 of 503 symbols collected | 65.21%
# RE..[done] | 176 of 503 symbols collected | 65.01%
# EXC..[done] | 177 of 503 symbols collected | 64.81%
# EXPE..[done] | 178 of 503 symbols collected | 64.61%
# EXPD..[done] | 179 of 503 symbols collected | 64.41%
# EXR..[done] | 180 of 503 symbols collected | 64.21%
# 'Requested level (Expiry) does not match index name (None)' XOM
# XOM..[done] | 181 of 503 symbols collected | 64.02%
# FFIV..[done] | 182 of 503 symbols collected | 63.82%
# 'Requested level (Expiry) does not match index name (None)' FB
# FB..[done] | 183 of 503 symbols collected | 63.62%
# FAST..[done] | 184 of 503 symbols collected | 63.42%
# FRT..[done] | 185 of 503 symbols collected | 63.22%
# FDX..[done] | 186 of 503 symbols collected | 63.02%
# FIS..[done] | 187 of 503 symbols collected | 62.82%
# FITB..[done] | 188 of 503 symbols collected | 62.62%
# FE..[done] | 189 of 503 symbols collected | 62.43%
# FRC..[done] | 190 of 503 symbols collected | 62.23%
# FISV..[done] | 191 of 503 symbols collected | 62.03%
# FLT..[done] | 192 of 503 symbols collected | 61.83%
# FLIR..[done] | 193 of 503 symbols collected | 61.63%
# FLS..[done] | 194 of 503 symbols collected | 61.43%
# FMC..[done] | 195 of 503 symbols collected | 61.23%
# F..[done] | 196 of 503 symbols collected | 61.03%
# FTNT..[done] | 197 of 503 symbols collected | 60.83%
# FTV..[done] | 198 of 503 symbols collected | 60.64%
# FBHS..[done] | 199 of 503 symbols collected | 60.44%
# FOXA..[done] | 200 of 503 symbols collected | 60.24%
# FOX..[done] | 201 of 503 symbols collected | 60.04%
# BEN..[done] | 202 of 503 symbols collected | 59.84%
# 'Requested level (Expiry) does not match index name (None)' FCX
# FCX..[done] | 203 of 503 symbols collected | 59.64%
# 'Requested level (Expiry) does not match index name (None)' GPS
# GPS..[done] | 204 of 503 symbols collected | 59.44%
# GRMN..[done] | 205 of 503 symbols collected | 59.24%
# IT..[done] | 206 of 503 symbols collected | 59.05%
# GD..[done] | 207 of 503 symbols collected | 58.85%
# GE..[done] | 208 of 503 symbols collected | 58.65%
# GIS..[done] | 209 of 503 symbols collected | 58.45%
# GM..[done] | 210 of 503 symbols collected | 58.25%
# GPC..[done] | 211 of 503 symbols collected | 58.05%
# GILD..[done] | 212 of 503 symbols collected | 57.85%
# GL..[done] | 213 of 503 symbols collected | 57.65%
# GPN..[done] | 214 of 503 symbols collected | 57.46%
# GS..[done] | 215 of 503 symbols collected | 57.26%
# GWW..[done] | 216 of 503 symbols collected | 57.06%
# HAL..[done] | 217 of 503 symbols collected | 56.86%
# HBI..[done] | 218 of 503 symbols collected | 56.66%
# HIG..[done] | 219 of 503 symbols collected | 56.46%
# HAS..[done] | 220 of 503 symbols collected | 56.26%
# HCA..[done] | 221 of 503 symbols collected | 56.06%
# PEAK..[done] | 222 of 503 symbols collected | 55.86%
# HSIC..[done] | 223 of 503 symbols collected | 55.67%
# HSY..[done] | 224 of 503 symbols collected | 55.47%
# HES..[done] | 225 of 503 symbols collected | 55.27%
# HPE..[done] | 226 of 503 symbols collected | 55.07%
# HLT..[done] | 227 of 503 symbols collected | 54.87%
# HFC..[done] | 228 of 503 symbols collected | 54.67%
# HOLX..[done] | 229 of 503 symbols collected | 54.47%
# 'Requested level (Expiry) does not match index name (None)' HD
# HD..[done] | 230 of 503 symbols collected | 54.27%
# HON..[done] | 231 of 503 symbols collected | 54.08%
# HRL..[done] | 232 of 503 symbols collected | 53.88%
# HST..[done] | 233 of 503 symbols collected | 53.68%
# HWM..[done] | 234 of 503 symbols collected | 53.48%
# HPQ..[done] | 235 of 503 symbols collected | 53.28%
# HUM..[done] | 236 of 503 symbols collected | 53.08%
# HBAN..[done] | 237 of 503 symbols collected | 52.88%
# HII..[done] | 238 of 503 symbols collected | 52.68%
# IEX..[done] | 239 of 503 symbols collected | 52.49%
# IDXX..[done] | 240 of 503 symbols collected | 52.29%
# INFO..[done] | 241 of 503 symbols collected | 52.09%
# ITW..[done] | 242 of 503 symbols collected | 51.89%
# ILMN..[done] | 243 of 503 symbols collected | 51.69%
# INCY..[done] | 244 of 503 symbols collected | 51.49%
# IR..[done] | 245 of 503 symbols collected | 51.29%
# INTC..[done] | 246 of 503 symbols collected | 51.09%
# ICE..[done] | 247 of 503 symbols collected | 50.89%
# IBM..[done] | 248 of 503 symbols collected | 50.70%
# IP..[done] | 249 of 503 symbols collected | 50.50%
# IPG..[done] | 250 of 503 symbols collected | 50.30%
# IFF..[done] | 251 of 503 symbols collected | 50.10%
# INTU..[done] | 252 of 503 symbols collected | 49.90%
# ISRG..[done] | 253 of 503 symbols collected | 49.70%
# IVZ..[done] | 254 of 503 symbols collected | 49.50%
# IPGP..[done] | 255 of 503 symbols collected | 49.30%
# IQV..[done] | 256 of 503 symbols collected | 49.11%
# IRM..[done] | 257 of 503 symbols collected | 48.91%
# JKHY..[done] | 258 of 503 symbols collected | 48.71%
# J..[done] | 259 of 503 symbols collected | 48.51%
# 'Requested level (Expiry) does not match index name (None)' JBHT
# JBHT..[done] | 260 of 503 symbols collected | 48.31%
# SJM..[done] | 261 of 503 symbols collected | 48.11%
# JNJ..[done] | 262 of 503 symbols collected | 47.91%
# JCI..[done] | 263 of 503 symbols collected | 47.71%
# JPM..[done] | 264 of 503 symbols collected | 47.51%
# JNPR..[done] | 265 of 503 symbols collected | 47.32%
# KSU..[done] | 266 of 503 symbols collected | 47.12%
# K..[done] | 267 of 503 symbols collected | 46.92%
# KEY..[done] | 268 of 503 symbols collected | 46.72%
# KEYS..[done] | 269 of 503 symbols collected | 46.52%
# KMB..[done] | 270 of 503 symbols collected | 46.32%
# KIM..[done] | 271 of 503 symbols collected | 46.12%
# KMI..[done] | 272 of 503 symbols collected | 45.92%
# KLAC..[done] | 273 of 503 symbols collected | 45.73%
# KHC..[done] | 274 of 503 symbols collected | 45.53%
# KR..[done] | 275 of 503 symbols collected | 45.33%
# LB..[done] | 276 of 503 symbols collected | 45.13%
# LHX..[done] | 277 of 503 symbols collected | 44.93%
# LH..[done] | 278 of 503 symbols collected | 44.73%
# LRCX..[done] | 279 of 503 symbols collected | 44.53%
# LW..[done] | 280 of 503 symbols collected | 44.33%
# LVS..[done] | 281 of 503 symbols collected | 44.14%
# LEG..[done] | 282 of 503 symbols collected | 43.94%
# LDOS..[done] | 283 of 503 symbols collected | 43.74%
# LEN..[done] | 284 of 503 symbols collected | 43.54%
# LLY..[done] | 285 of 503 symbols collected | 43.34%
# LNC..[done] | 286 of 503 symbols collected | 43.14%
# LIN..[done] | 287 of 503 symbols collected | 42.94%
# LYV..[done] | 288 of 503 symbols collected | 42.74%
# LKQ..[done] | 289 of 503 symbols collected | 42.54%
# LMT..[done] | 290 of 503 symbols collected | 42.35%
# L..[done] | 291 of 503 symbols collected | 42.15%
# LOW..[done] | 292 of 503 symbols collected | 41.95%
# LUMN..[done] | 293 of 503 symbols collected | 41.75%
# LYB..[done] | 294 of 503 symbols collected | 41.55%
# MTB..[done] | 295 of 503 symbols collected | 41.35%
# MRO..[done] | 296 of 503 symbols collected | 41.15%
# MPC..[done] | 297 of 503 symbols collected | 40.95%
# MKTX..[done] | 298 of 503 symbols collected | 40.76%
# MAR..[done] | 299 of 503 symbols collected | 40.56%
# MMC..[done] | 300 of 503 symbols collected | 40.36%
# MLM..[done] | 301 of 503 symbols collected | 40.16%
# MAS..[done] | 302 of 503 symbols collected | 39.96%
# MA..[done] | 303 of 503 symbols collected | 39.76%
# MKC..[done] | 304 of 503 symbols collected | 39.56%
# MXIM..[done] | 305 of 503 symbols collected | 39.36%
# MCD..[done] | 306 of 503 symbols collected | 39.17%
# MCK..[done] | 307 of 503 symbols collected | 38.97%
# MDT..[done] | 308 of 503 symbols collected | 38.77%
# MRK..[done] | 309 of 503 symbols collected | 38.57%
# MET..[done] | 310 of 503 symbols collected | 38.37%
# MTD..[done] | 311 of 503 symbols collected | 38.17%
# MGM..[done] | 312 of 503 symbols collected | 37.97%
# MCHP..[done] | 313 of 503 symbols collected | 37.77%
# MU..[done] | 314 of 503 symbols collected | 37.57%
# 'Requested level (Expiry) does not match index name (None)' MSFT
# MSFT..[done] | 315 of 503 symbols collected | 37.38%
# MAA..[done] | 316 of 503 symbols collected | 37.18%
# MHK..[done] | 317 of 503 symbols collected | 36.98%
# TAP..[done] | 318 of 503 symbols collected | 36.78%
# MDLZ..[done] | 319 of 503 symbols collected | 36.58%
# MPWR..[done] | 320 of 503 symbols collected | 36.38%
# MNST..[done] | 321 of 503 symbols collected | 36.18%
# MCO..[done] | 322 of 503 symbols collected | 35.98%
# MS..[done] | 323 of 503 symbols collected | 35.79%
# MOS..[done] | 324 of 503 symbols collected | 35.59%
# MSI..[done] | 325 of 503 symbols collected | 35.39%
# MSCI..[done] | 326 of 503 symbols collected | 35.19%
# NDAQ..[done] | 327 of 503 symbols collected | 34.99%
# NTAP..[done] | 328 of 503 symbols collected | 34.79%
# NFLX..[done] | 329 of 503 symbols collected | 34.59%
# NWL..[done] | 330 of 503 symbols collected | 34.39%
# NEM..[done] | 331 of 503 symbols collected | 34.19%
# NWSA..[done] | 332 of 503 symbols collected | 34.00%
# NWS..[done] | 333 of 503 symbols collected | 33.80%
# NEE..[done] | 334 of 503 symbols collected | 33.60%
# NLSN..[done] | 335 of 503 symbols collected | 33.40%
# NKE..[done] | 336 of 503 symbols collected | 33.20%
# NI..[done] | 337 of 503 symbols collected | 33.00%
# NSC..[done] | 338 of 503 symbols collected | 32.80%
# NTRS..[done] | 339 of 503 symbols collected | 32.60%
# NOC..[done] | 340 of 503 symbols collected | 32.41%
# NLOK..[done] | 341 of 503 symbols collected | 32.21%
# NCLH..[done] | 342 of 503 symbols collected | 32.01%
# NOV..[done] | 343 of 503 symbols collected | 31.81%
# NRG..[done] | 344 of 503 symbols collected | 31.61%
# NUE..[done] | 345 of 503 symbols collected | 31.41%
# NVDA..[done] | 346 of 503 symbols collected | 31.21%
# Data not available NVR
# NVR..[done] | 347 of 503 symbols collected | 31.01%
# ORLY..[done] | 348 of 503 symbols collected | 30.82%
# OXY..[done] | 349 of 503 symbols collected | 30.62%
# ODFL..[done] | 350 of 503 symbols collected | 30.42%
# OMC..[done] | 351 of 503 symbols collected | 30.22%
# OKE..[done] | 352 of 503 symbols collected | 30.02%
# ORCL..[done] | 353 of 503 symbols collected | 29.82%
# OTIS..[done] | 354 of 503 symbols collected | 29.62%
# PCAR..[done] | 355 of 503 symbols collected | 29.42%
# PKG..[done] | 356 of 503 symbols collected | 29.22%
# PH..[done] | 357 of 503 symbols collected | 29.03%
# PAYX..[done] | 358 of 503 symbols collected | 28.83%
# PAYC..[done] | 359 of 503 symbols collected | 28.63%
# PYPL..[done] | 360 of 503 symbols collected | 28.43%
# PNR..[done] | 361 of 503 symbols collected | 28.23%
# PBCT..[done] | 362 of 503 symbols collected | 28.03%
# PEP..[done] | 363 of 503 symbols collected | 27.83%
# PKI..[done] | 364 of 503 symbols collected | 27.63%
# PRGO..[done] | 365 of 503 symbols collected | 27.44%
# PFE..[done] | 366 of 503 symbols collected | 27.24%
# PM..[done] | 367 of 503 symbols collected | 27.04%
# PSX..[done] | 368 of 503 symbols collected | 26.84%
# PNW..[done] | 369 of 503 symbols collected | 26.64%
# PXD..[done] | 370 of 503 symbols collected | 26.44%
# PNC..[done] | 371 of 503 symbols collected | 26.24%
# POOL..[done] | 372 of 503 symbols collected | 26.04%
# PPG..[done] | 373 of 503 symbols collected | 25.84%
# PPL..[done] | 374 of 503 symbols collected | 25.65%
# PFG..[done] | 375 of 503 symbols collected | 25.45%
# PG..[done] | 376 of 503 symbols collected | 25.25%
# PGR..[done] | 377 of 503 symbols collected | 25.05%
# PLD..[done] | 378 of 503 symbols collected | 24.85%
# PRU..[done] | 379 of 503 symbols collected | 24.65%
# PEG..[done] | 380 of 503 symbols collected | 24.45%
# PSA..[done] | 381 of 503 symbols collected | 24.25%
# PHM..[done] | 382 of 503 symbols collected | 24.06%
# PVH..[done] | 383 of 503 symbols collected | 23.86%
# QRVO..[done] | 384 of 503 symbols collected | 23.66%
# PWR..[done] | 385 of 503 symbols collected | 23.46%
# QCOM..[done] | 386 of 503 symbols collected | 23.26%
# DGX..[done] | 387 of 503 symbols collected | 23.06%
# RL..[done] | 388 of 503 symbols collected | 22.86%
# RJF..[done] | 389 of 503 symbols collected | 22.66%
# RTX..[done] | 390 of 503 symbols collected | 22.47%
# O..[done] | 391 of 503 symbols collected | 22.27%
# REG..[done] | 392 of 503 symbols collected | 22.07%
# REGN..[done] | 393 of 503 symbols collected | 21.87%
# RF..[done] | 394 of 503 symbols collected | 21.67%
# RSG..[done] | 395 of 503 symbols collected | 21.47%
# RMD..[done] | 396 of 503 symbols collected | 21.27%
# RHI..[done] | 397 of 503 symbols collected | 21.07%
# ROK..[done] | 398 of 503 symbols collected | 20.87%
# ROL..[done] | 399 of 503 symbols collected | 20.68%
# ROP..[done] | 400 of 503 symbols collected | 20.48%
# ROST..[done] | 401 of 503 symbols collected | 20.28%
# 'Requested level (Expiry) does not match index name (None)' RCL
# RCL..[done] | 402 of 503 symbols collected | 20.08%
# SPGI..[done] | 403 of 503 symbols collected | 19.88%
# CRM..[done] | 404 of 503 symbols collected | 19.68%
# SBAC..[done] | 405 of 503 symbols collected | 19.48%
# SLB..[done] | 406 of 503 symbols collected | 19.28%
# STX..[done] | 407 of 503 symbols collected | 19.09%
# SEE..[done] | 408 of 503 symbols collected | 18.89%
# SRE..[done] | 409 of 503 symbols collected | 18.69%
# NOW..[done] | 410 of 503 symbols collected | 18.49%
# SHW..[done] | 411 of 503 symbols collected | 18.29%
# SPG..[done] | 412 of 503 symbols collected | 18.09%
# SWKS..[done] | 413 of 503 symbols collected | 17.89%
# SLG..[done] | 414 of 503 symbols collected | 17.69%
# SNA..[done] | 415 of 503 symbols collected | 17.50%
# SO..[done] | 416 of 503 symbols collected | 17.30%
# LUV..[done] | 417 of 503 symbols collected | 17.10%
# SWK..[done] | 418 of 503 symbols collected | 16.90%
# 'Requested level (Expiry) does not match index name (None)' SBUX
# SBUX..[done] | 419 of 503 symbols collected | 16.70%
# STT..[done] | 420 of 503 symbols collected | 16.50%
# STE..[done] | 421 of 503 symbols collected | 16.30%
# SYK..[done] | 422 of 503 symbols collected | 16.10%
# SIVB..[done] | 423 of 503 symbols collected | 15.90%
# SYF..[done] | 424 of 503 symbols collected | 15.71%
# SNPS..[done] | 425 of 503 symbols collected | 15.51%
# SYY..[done] | 426 of 503 symbols collected | 15.31%
# TMUS..[done] | 427 of 503 symbols collected | 15.11%
# TROW..[done] | 428 of 503 symbols collected | 14.91%
# TTWO..[done] | 429 of 503 symbols collected | 14.71%
# TPR..[done] | 430 of 503 symbols collected | 14.51%
# TGT..[done] | 431 of 503 symbols collected | 14.31%
# TEL..[done] | 432 of 503 symbols collected | 14.12%
# TDY..[done] | 433 of 503 symbols collected | 13.92%
# TFX..[done] | 434 of 503 symbols collected | 13.72%
# TER..[done] | 435 of 503 symbols collected | 13.52%
# TSLA..[done] | 436 of 503 symbols collected | 13.32%
# TXN..[done] | 437 of 503 symbols collected | 13.12%
# TXT..[done] | 438 of 503 symbols collected | 12.92%
# TMO..[done] | 439 of 503 symbols collected | 12.72%
# TJX..[done] | 440 of 503 symbols collected | 12.52%
# TSCO..[done] | 441 of 503 symbols collected | 12.33%
# TT..[done] | 442 of 503 symbols collected | 12.13%
# TDG..[done] | 443 of 503 symbols collected | 11.93%
# TRV..[done] | 444 of 503 symbols collected | 11.73%
# TRMB..[done] | 445 of 503 symbols collected | 11.53%
# TFC..[done] | 446 of 503 symbols collected | 11.33%
# 'Requested level (Expiry) does not match index name (None)' TWTR
# TWTR..[done] | 447 of 503 symbols collected | 11.13%
# TYL..[done] | 448 of 503 symbols collected | 10.93%
# TSN..[done] | 449 of 503 symbols collected | 10.74%
# UDR..[done] | 450 of 503 symbols collected | 10.54%
# ULTA..[done] | 451 of 503 symbols collected | 10.34%
# USB..[done] | 452 of 503 symbols collected | 10.14%
# UAA..[done] | 453 of 503 symbols collected | 9.94%
# UA..[done] | 454 of 503 symbols collected | 9.74%
# UNP..[done] | 455 of 503 symbols collected | 9.54%
# UAL..[done] | 456 of 503 symbols collected | 9.34%
# UNH..[done] | 457 of 503 symbols collected | 9.15%
# UPS..[done] | 458 of 503 symbols collected | 8.95%
# URI..[done] | 459 of 503 symbols collected | 8.75%
# UHS..[done] | 460 of 503 symbols collected | 8.55%
# UNM..[done] | 461 of 503 symbols collected | 8.35%
# VLO..[done] | 462 of 503 symbols collected | 8.15%
# VAR..[done] | 463 of 503 symbols collected | 7.95%
# VTR..[done] | 464 of 503 symbols collected | 7.75%
# VRSN..[done] | 465 of 503 symbols collected | 7.55%
# VRSK..[done] | 466 of 503 symbols collected | 7.36%
# VZ..[done] | 467 of 503 symbols collected | 7.16%
# 'Requested level (Expiry) does not match index name (None)' VRTX
# VRTX..[done] | 468 of 503 symbols collected | 6.96%
# VFC..[done] | 469 of 503 symbols collected | 6.76%
# VIAC..[done] | 470 of 503 symbols collected | 6.56%
# VTRS..[done] | 471 of 503 symbols collected | 6.36%
# V..[done] | 472 of 503 symbols collected | 6.16%
# VNT..[done] | 473 of 503 symbols collected | 5.96%
# VNO..[done] | 474 of 503 symbols collected | 5.77%
# VMC..[done] | 475 of 503 symbols collected | 5.57%
# WRB..[done] | 476 of 503 symbols collected | 5.37%
# WAB..[done] | 477 of 503 symbols collected | 5.17%
# WMT..[done] | 478 of 503 symbols collected | 4.97%
# WBA..[done] | 479 of 503 symbols collected | 4.77%
# DIS..[done] | 480 of 503 symbols collected | 4.57%
# WM..[done] | 481 of 503 symbols collected | 4.37%
# WAT..[done] | 482 of 503 symbols collected | 4.17%
# WEC..[done] | 483 of 503 symbols collected | 3.98%
# WFC..[done] | 484 of 503 symbols collected | 3.78%
# WELL..[done] | 485 of 503 symbols collected | 3.58%
# WST..[done] | 486 of 503 symbols collected | 3.38%
# 'Requested level (Expiry) does not match index name (None)' WDC
# WDC..[done] | 487 of 503 symbols collected | 3.18%
# WU..[done] | 488 of 503 symbols collected | 2.98%
# WRK..[done] | 489 of 503 symbols collected | 2.78%
# WY..[done] | 490 of 503 symbols collected | 2.58%
# WHR..[done] | 491 of 503 symbols collected | 2.39%
# WMB..[done] | 492 of 503 symbols collected | 2.19%
# WLTW..[done] | 493 of 503 symbols collected | 1.99%
# WYNN..[done] | 494 of 503 symbols collected | 1.79%
# XEL..[done] | 495 of 503 symbols collected | 1.59%
# XRX..[done] | 496 of 503 symbols collected | 1.39%
# XLNX..[done] | 497 of 503 symbols collected | 1.19%
# XYL..[done] | 498 of 503 symbols collected | 0.99%
# YUM..[done] | 499 of 503 symbols collected | 0.80%
# ZBRA..[done] | 500 of 503 symbols collected | 0.60%
# ZBH..[done] | 501 of 503 symbols collected | 0.40%
# ZION..[done] | 502 of 503 symbols collected | 0.20%
# ZTS..[done] | 503 of 503 symbols collected | 0.00%
# ['ADM', 'BIIB', 'BWA', 'CF', 'SCHW', 'COP', 'DVN', 'DXCM', 'DOW', 'EOG', 'XOM', 'FB', 'FCX', 'GPS', 'HD', 'JBHT', 'MSFT', 'NVR', 'RCL', 'SBUX', 'TWTR', 'VRTX', 'WDC']

# %%
_df
# Out:
#    Strike     Expiry  Type   Last    Bid    Ask  Chg   Vol Open_Int        IV  \
# 0   150.0 2021-03-05  call  26.85  25.05  28.00  0.0   2.0      2.0  1.350589
# 1   160.0 2021-03-05  call  15.56  15.45  17.65  0.0   1.0      1.0  0.864747
# 2   162.5 2021-03-05  call  15.30   0.00   0.00  0.0   1.0      0.0  0.000010
# 3   165.0 2021-03-05  call  11.98  10.45  12.80  0.0   2.0     16.0  0.703860
# 4   167.5 2021-03-05  call  10.50   6.70  10.55  0.0   2.0      2.0  0.649906
# ..    ...        ...   ...    ...    ...    ...  ...   ...      ...       ...
# 12  165.0 2023-01-20   put  25.18  25.50  30.50  0.0   1.0      1.0  0.296302
# 13  170.0 2023-01-20   put  27.36  28.50  33.50  0.0   NaN     12.0  0.293647
# 14  180.0 2023-01-20   put  35.20  31.30  34.70  0.0   NaN      1.0  0.226112
# 15  200.0 2023-01-20   put  52.95  51.50  56.00  0.0  37.0     11.0  0.301307
# 16  220.0 2023-01-20   put  65.93  66.00  71.00  0.0   2.0      4.0  0.280983
#
#    Underlying_Price Symbol
# 0           176.585    MMM
# 1           176.585    MMM
# 2           176.585    MMM
# 3           176.585    MMM
# 4           176.585    MMM
# ..              ...    ...
# 12          156.270    ZTS
# 13          156.270    ZTS
# 14          156.270    ZTS
# 15          156.270    ZTS
# 16          156.270    ZTS
#
# [186810 rows x 12 columns]

# %%
_df.to_excel("../data/option_data/xlsx/sp500_options.xlsx")
